# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\mltla\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\mltla\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\mltla\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "0"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q1 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))[:-2]
        featurelist = sorted(list(set(resultsDF.nFeatures)))[:-3]
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q1.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "0"
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))[:-2]
        featurelist = sorted(list(set(resultsDF.nFeatures)))[:-3]
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q1.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "0"
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))[:-2]
        featurelist = sorted(list(set(resultsDF.nFeatures)))[:-3]
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q1.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "0"
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))[:-2]
        featurelist = sorted(list(set(resultsDF.nFeatures)))[:-3]
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q1.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "1"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q2 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q2.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q2.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q2.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q2.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "2"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q3 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q3.append(blist)

#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q3.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q3.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q3.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "3"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q4 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q4.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q4.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q4.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q4.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "4"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q5 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q5.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q5.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q5.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q5.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "5"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q6 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q6.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q6.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q6.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q6.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "6"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q7 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q7.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q7.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q7.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q7.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 2
label = "7"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q8 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q8.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q8.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q8.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q8.append(blist)

# %%
#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 1
label = "8"
filenameList = ["callIn14_4", "callIn14_6","callIn14_12","callIn14_24"]
title = "Incoming Calls"

Q9 = []
blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q9.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["callOut14_4", "callOut14_6","callOut14_12","callOut14_24"]
title = "Outgoing Calls"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q9.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textIn14_4", "textIn14_6","textIn14_12","textIn14_24"]
title = "Incoming Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q9.append(blist)


#filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24"]#, "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
filenameList = ["textOut14_4", "textOut14_6","textOut14_12","textOut14_24"]
title = "Outgoing Texts"

blist = []
for filename2 in filename2List:  
    blist2 = []
    for filename in filenameList:    

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = [] #stores best value resultsDF

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(max(values))
    
        blist2.append(max(balancedAcc))
    blist.append(blist2)

legendlist = ["Length", "Count", "Contacts"]
markers = ['^', '>', '^', '<']
plt.figure(figsize = (4.475, 4))
for i in range(0, len(blist)):
    plt.plot(['4','6','12','24'], blist[i], marker = markers[i], label = legendlist[i], linewidth=2, markersize=12)

plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title(title + " for Q" + str(int(label)+1), fontsize = 15)
plt.legend(ncol=3,loc=3)

#plt.savefig("anxietyCAT.png", bbox_inches = "tight")
plt.show()
plt.close()
Q9.append(blist)

# %%
Q = Q9
print(str(round(Q[0][0][0],2))+"&"+str(round(Q[0][0][1],2))+"&"+str(round(Q[0][0][2],2))+"&"+str(round(Q[0][0][3],2))
     +"&"+str(round(Q[1][0][0],2))+"&"+str(round(Q[1][0][1],2))+"&"+str(round(Q[1][0][2],2))+"&"+str(round(Q[1][0][3],2))
     +"&"+str(round(Q[2][0][0],2))+"&"+str(round(Q[2][0][1],2))+"&"+str(round(Q[2][0][2],2))+"&"+str(round(Q[2][0][3],2))
     +"&"+str(round(Q[3][0][0],2))+"&"+str(round(Q[3][0][1],2))+"&"+str(round(Q[3][0][2],2))+"&"+str(round(Q[3][0][3],2)))

print(str(round(Q[0][1][0],2))+"&"+str(round(Q[0][1][1],2))+"&"+str(round(Q[0][1][2],2))+"&"+str(round(Q[0][1][3],2))
     +"&"+str(round(Q[1][1][0],2))+"&"+str(round(Q[1][1][1],2))+"&"+str(round(Q[1][1][2],2))+"&"+str(round(Q[1][1][3],2))
     +"&"+str(round(Q[2][1][0],2))+"&"+str(round(Q[2][1][1],2))+"&"+str(round(Q[2][1][2],2))+"&"+str(round(Q[2][1][3],2))
     +"&"+str(round(Q[3][1][0],2))+"&"+str(round(Q[3][1][1],2))+"&"+str(round(Q[3][1][2],2))+"&"+str(round(Q[3][1][3],2)))

print(str(round(Q[0][2][0],2))+"&"+str(round(Q[0][2][1],2))+"&"+str(round(Q[0][2][2],2))+"&"+str(round(Q[0][2][3],2))
     +"&"+str(round(Q[1][2][0],2))+"&"+str(round(Q[1][2][1],2))+"&"+str(round(Q[1][2][2],2))+"&"+str(round(Q[1][2][3],2))
     +"&"+str(round(Q[2][2][0],2))+"&"+str(round(Q[2][2][1],2))+"&"+str(round(Q[2][2][2],2))+"&"+str(round(Q[2][2][3],2))
     +"&"+str(round(Q[3][2][0],2))+"&"+str(round(Q[3][2][1],2))+"&"+str(round(Q[3][2][2],2))+"&"+str(round(Q[3][2][3],2)))
# Out:
# 0.56&0.54&0.56&0.62&0.56&0.58&0.56&0.58&0.55&0.56&0.61&0.6&0.62&0.63&0.66&0.66
# 0.58&0.6&0.55&0.59&0.53&0.53&0.52&0.56&0.58&0.55&0.56&0.56&0.63&0.61&0.59&0.65
# 0.59&0.6&0.57&0.58&0.59&0.6&0.57&0.58&0.56&0.55&0.6&0.57&0.64&0.64&0.64&0.67

# %%
IC4len = [Q1[0][0][0], Q2[0][0][0], Q3[0][0][0], Q4[0][0][0], Q5[0][0][0], Q6[0][0][0],Q7[0][0][0], Q8[0][0][0], Q9[0][0][0]]
IC6len = [Q1[0][0][1], Q2[0][0][1], Q3[0][0][1], Q4[0][0][1], Q5[0][0][1], Q6[0][0][1],Q7[0][0][1], Q8[0][0][1], Q9[0][0][1]]
IC12len = [Q1[0][0][2], Q2[0][0][2], Q3[0][0][2], Q4[0][0][2], Q5[0][0][2], Q6[0][0][2],Q7[0][0][2], Q8[0][0][2], Q9[0][0][2]]
IC24len = [Q1[0][0][3], Q2[0][0][3], Q3[0][0][3], Q4[0][0][3], Q5[0][0][3], Q6[0][0][3],Q7[0][0][3], Q8[0][0][3], Q9[0][0][3]]

OC4len = [Q1[1][0][0], Q2[1][0][0], Q3[1][0][0], Q4[1][0][0], Q5[1][0][0], Q6[1][0][0],Q7[1][0][0], Q8[1][0][0], Q9[1][0][0]]
OC6len = [Q1[1][0][1], Q2[1][0][1], Q3[1][0][1], Q4[1][0][1], Q5[1][0][1], Q6[1][0][1],Q7[1][0][1], Q8[1][0][1], Q9[1][0][1]]
OC12len = [Q1[1][0][2], Q2[1][0][2], Q3[1][0][2], Q4[1][0][2], Q5[1][0][2], Q6[1][0][2],Q7[1][0][2], Q8[1][0][2], Q9[1][0][2]]
OC24len = [Q1[1][0][3], Q2[1][0][3], Q3[1][0][3], Q4[1][0][3], Q5[1][0][3], Q6[1][0][3],Q7[1][0][3], Q8[1][0][3], Q9[1][0][3]]

IT4len = [Q1[2][0][0], Q2[2][0][0], Q3[2][0][0], Q4[2][0][0], Q5[2][0][0], Q6[2][0][0],Q7[2][0][0], Q8[2][0][0], Q9[2][0][0]]
IT4con = [Q1[2][2][0], Q2[2][2][0], Q3[2][2][0], Q4[2][2][0], Q5[2][2][0], Q6[2][2][0],Q7[2][2][0], Q8[2][2][0], Q9[2][2][0]]
IT6con = [Q1[2][2][1], Q2[2][2][1], Q3[2][2][1], Q4[2][2][1], Q5[2][2][1], Q6[2][2][1],Q7[2][2][1], Q8[2][2][1], Q9[2][2][1]]
IT12con = [Q1[2][2][2], Q2[2][2][2], Q3[2][2][2], Q4[2][2][2], Q5[2][2][2], Q6[2][2][2],Q7[2][2][2], Q8[2][2][2], Q9[2][2][2]]
IT24con = [Q1[2][2][3], Q2[2][2][3], Q3[2][2][3], Q4[2][2][3], Q5[2][2][3], Q6[2][2][3],Q7[2][2][3], Q8[2][2][3], Q9[2][2][3]]

OT4con = [Q1[3][2][0], Q2[3][2][0], Q3[3][2][0], Q4[3][2][0], Q5[3][2][0], Q6[3][2][0],Q7[3][2][0], Q8[3][2][0], Q9[3][2][0]]
OT6con = [Q1[3][2][1], Q2[3][2][1], Q3[3][2][1], Q4[3][2][1], Q5[3][2][1], Q6[3][2][1],Q7[3][2][1], Q8[3][2][1], Q9[3][2][1]]
OT12con = [Q1[3][2][2], Q2[3][2][2], Q3[3][2][2], Q4[3][2][2], Q5[3][2][2], Q6[3][2][2],Q7[3][2][2], Q8[3][2][2], Q9[3][2][2]]
OT24con = [Q1[3][2][3], Q2[3][2][3], Q3[3][2][3], Q4[3][2][3], Q5[3][2][3], Q6[3][2][3],Q7[3][2][3], Q8[3][2][3], Q9[3][2][3]]

# %%
legendlist = ["Length", "Count", "Contacts"]
plt.figure(figsize = (4.475, 4))
plt.plot(['4','6','12','24'], [sum(IC4len)/9, sum(IC6len)/9, sum(IC12len)/9, sum(IC24len)/9], marker = '^', label = "Length", linewidth=2, markersize=12)
plt.plot(['4','6','12','24'], [sum(IC4cnt)/9, sum(IC6cnt)/9, sum(IC12cnt)/9, sum(IC24cnt)/9], marker = '.', label = "Count", linewidth=2, markersize=15)
plt.plot(['4','6','12','24'], [sum(IC4con)/9, sum(IC6con)/9, sum(IC12con)/9, sum(IC24con)/9], marker = 's', label = "Contacts", linewidth=2, markersize=12)
plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title("Incoming Calls", fontsize = 15)
plt.legend(ncol=3,loc=3)

# %%
legendlist = ["Length", "Count", "Contacts"]
plt.figure(figsize = (4.475, 4))
plt.plot(['4','6','12','24'], [sum(OT4len)/9, sum(OT6len)/9, sum(OT12len)/9, sum(OT24len)/9], marker = '^', label = "Length", linewidth=2, markersize=12)
plt.plot(['4','6','12','24'], [sum(OT4cnt)/9, sum(OT6cnt)/9, sum(OT12cnt)/9, sum(OT24cnt)/9], marker = '.', label = "Count", linewidth=2, markersize=15)
plt.plot(['4','6','12','24'], [sum(OT4con)/9, sum(OT6con)/9, sum(OT12con)/9, sum(OT24con)/9], marker = 's', label = "Contacts", linewidth=2, markersize=12)
plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title("Outgoing Texts", fontsize = 15)
plt.legend(ncol=3,loc=3)

# %%
legendlist = ["Length", "Count", "Contacts"]
plt.figure(figsize = (4.475, 4))
plt.plot(['4','6','12','24'], [sum(IT4len)/9, sum(IT6len)/9, sum(IT12len)/9, sum(IT24len)/9], marker = '^', label = "Length", linewidth=2, markersize=12)
plt.plot(['4','6','12','24'], [sum(IT4cnt)/9, sum(IT6cnt)/9, sum(IT12cnt)/9, sum(IT24cnt)/9], marker = '.', label = "Count", linewidth=2, markersize=15)
plt.plot(['4','6','12','24'], [sum(IT4con)/9, sum(IT6con)/9, sum(IT12con)/9, sum(IT24con)/9], marker = 's', label = "Contacts", linewidth=2, markersize=12)
plt.ylim(0.25, 0.75)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title("Incoming Texts", fontsize = 15)
plt.legend(ncol=3,loc=3)

# %%
legendlist = ["Length", "Count", "Contacts"]
plt.figure(figsize = (4.15, 3))
plt.plot(['4','6','12','24'], [sum(IC4len)/9, sum(IC6len)/9, sum(IC12len)/9, sum(IC24len)/9], marker = '^', label = "Incoming Call", linewidth=2, markersize=12)
plt.plot(['4','6','12','24'], [sum(OC4len)/9, sum(OC6len)/9, sum(OC12len)/9, sum(OC24len)/9], marker = '^', label = "Outgoing Call", linewidth=2, markersize=12)
plt.plot(['4','6','12','24'], [sum(IT4len)/9, sum(IT6len)/9, sum(IT12len)/9, sum(IT24len)/9], marker = '^', label = "Incoming Text", linewidth=2, markersize=12)
plt.plot(['4','6','12','24'], [sum(OT4len)/9, sum(OT6len)/9, sum(OT12len)/9, sum(OT24len)/9], marker = '^', label = "Outgoing Text", linewidth=2, markersize=12)
plt.ylim(0.425, 0.725)
plt.xlabel("Aggregation Interval", fontsize = 12)
plt.ylabel("Balanced Accuracy", fontsize = 12)
plt.title("Average Communication Length", fontsize = 15)
plt.legend(ncol=2,loc=3)

# %%
filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24", "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 1
label = "8"

for filename in filenameList:
    for filename2 in filename2List:

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")

        modellist = sorted(list(set(resultsDF.model)))
        featurelist = sorted(list(set(resultsDF.nFeatures)))
        balancedAcc = []

        for model in modellist:
            values = []
            for features in featurelist:
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                ba = (sen+spec)/2

                values.append(ba)
            balancedAcc.append(values)

        #modellist = ["LR", "NB", "RF", "SVC", "XGBoost", "kNN"]

        markers = ['s', '^', '>', '^', '<', 'o']
        plt.figure(figsize = (6, 4))
        for i in range(0, len(balancedAcc)):
            plt.plot(featurelist, balancedAcc[i], marker = markers[i], label = modellist[i], linewidth=2, markersize=12)

        plt.ylim(0.25, 0.75)
        plt.xlabel("Principal Components", fontsize = 12)
        plt.ylabel("Balanced Accuracy", fontsize = 12)
        plt.title(filename + filename2, fontsize = 15)
        plt.legend(ncol=3,loc=3)

        #plt.savefig("anxietyCAT.png", bbox_inches = "tight")
        plt.show()
        plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-169-b790e3c8b3ce> in <module>
#       7     for filename2 in filename2List:
#       8
# ----> 9         resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")
#      10
#      11         modellist = sorted(list(set(resultsDF.model)))
#
# ...

# %%
filenameList = ["callIn14_4", "callOut14_4", "textIn14_4", "textOut14_4", "callIn14_6", "callOut14_6", "textIn14_6", "textOut14_6", "callIn14_12", "callOut14_12", "textIn14_12", "textOut14_12", "callIn14_24", "callOut14_24", "textIn14_24", "textOut14_24", "callAll14_4", "callAll14_6","callAll14_12", "callAll14_24", "textAll14_4", "textAll14_6", "textAll14_12", "textAll14_24"]
filename2List = ["_average_length", "_counts", "_unique_contacts"]
split = 1
label = "8"

prev = 0
for filename in filenameList:    
    for filename2 in filename2List:

        resultsDF = pd.read_csv("results/" + filename + filename2 + "Q" + label + "score" + str(split) + ".csv")


        for model in set(resultsDF.model):
            for features in set(resultsDF.nFeatures):
                tempdf = resultsDF[(resultsDF.model == model) & (resultsDF.nFeatures == features)]

                sen = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falseNeg))
                spec = sum(tempdf.trueNeg)/(sum(tempdf.trueNeg) + sum(tempdf.falsePos))
                prec = sum(tempdf.truePos)/(sum(tempdf.truePos) + sum(tempdf.falsePos))
                ba = (sen+spec)/2
                f1 = (2*prec*sen)/(prec + sen)
                acc = (sum(tempdf.truePos) + sum(tempdf.trueNeg))/tempdf.shape[0]
                if ba>=(prev):
                    prev = ba
                    print(filename + filename2)
                    print(model)
                    print(features)
                    print("TP = " + str(sum(tempdf.truePos)))
                    print("FP = " + str(sum(tempdf.falsePos)))
                    print("FN = " + str(sum(tempdf.falseNeg)))
                    print("TN = " + str(sum(tempdf.trueNeg)))
                    print("Bal Acc = " + str(ba))
                    print("F1 = " + str(f1))
                    print("Acc = " + str(acc))
                    print("Sens = " + str(sen))
                    print("Spec = " + str(spec))

        print("___________________________________________________________")
# Out:
# callIn14_4_average_length
# NB
# 1
# TP = 50
# FP = 79
# FN = 26
# TN = 27
# Bal Acc = 0.4563058589870904
# F1 = 0.48780487804878053
# Acc = 0.4230769230769231
# Sens = 0.6578947368421053
# Spec = 0.25471698113207547
# callIn14_4_average_length
# NB
# 2
# TP = 52
# FP = 77
# FN = 24
# TN = 29
# Bal Acc = 0.4788977159880834
# F1 = 0.5073170731707317
# Acc = 0.44505494505494503
# Sens = 0.6842105263157895
# Spec = 0.27358490566037735
# callIn14_4_average_length
# NB
# 3
# TP = 46
# FP = 62
# FN = 30
# TN = 44
# Bal Acc = 0.5101787487586892
# F1 = 0.5
# Acc = 0.4945054945054945
# Sens = 0.6052631578947368
# Spec = 0.41509433962264153
# callIn14_4_average_length
# RF
# 2
# TP = 30
# FP = 33
# FN = 46
# TN = 73
# Bal Acc = 0.541708043694141
# F1 = 0.4316546762589928
# Acc = 0.5659340659340659
# Sens = 0.39473684210526316
# Spec = 0.6886792452830188
# callIn14_4_average_length
# SVC
# 4
# TP = 48
# FP = 55
# FN = 28
# TN = 51
# Bal Acc = 0.5563555114200596
# F1 = 0.5363128491620112
# ...

# %%
featureE = "PCA"
modelTypelist = ["NB","LR1","SVC1", "kNN5", "RF", "XG"]
dfindex = -10

filenameList = ["textIn14_4", "textOut14_4", "callIn14_4", "callOut14_4"]
filename2List = ["_average_length"]
split = 1
label = "8"

for filename in filenameList:
    for filename2 in filename2List:
        
        data = pd.read_csv("data/" + filename + filename2 + ".csv")
        
        d10 = []
        for i in range(0, data.shape[0]):
            if int(data[label][i]) >= split:
                d10.append(1)
            else:
                d10.append(0)
        data[label] = d10
        
        print(sum(d10)/len(d10)*100)
# Out:
# 44.827586206896555
# 53.535353535353536
# 41.75824175824176
# 41.11675126903553
